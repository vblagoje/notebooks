# %% [markdown]
# <a href="https://colab.research.google.com/github/vblagoje/notebooks/blob/main/haystack2x-experiments/chat_hf_local.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip uninstall -y llmx
# Out:
# Found existing installation: llmx 0.0.15a0
# Uninstalling llmx-0.0.15a0:
#   Successfully uninstalled llmx-0.0.15a0

# %%
# !pip install -q accelerate git+https://github.com/deepset-ai/haystack.git@hf_chat_support
# Out:
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 270.9/270.9 kB 4.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.1/212.1 kB 25.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.6/40.6 kB 5.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.9/75.9 kB 11.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.9/76.9 kB 10.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 8.8 MB/s eta 0:00:00
#   Building wheel for haystack-ai (pyproject.toml) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow-probability 0.22.0 requires typing-extensions<4.6.0, but you have typing-extensions 4.9.0 which is incompatible.

# %%
import torch

from haystack.components.generators.chat import HuggingFaceLocalChatGenerator
from haystack.dataclasses import ChatMessage
from haystack.components.generators.utils import default_streaming_callback

# %%
llm = HuggingFaceLocalChatGenerator(huggingface_pipeline_kwargs={"device_map":"auto"},
                                    streaming_callback=default_streaming_callback,
                                    generation_kwargs={"max_new_tokens": 350})
llm.warm_up()
# Out:
# config.json:   0%|          | 0.00/596 [00:00<?, ?B/s]
# model.safetensors.index.json:   0%|          | 0.00/25.1k [00:00<?, ?B/s]
# Downloading shards:   0%|          | 0/3 [00:00<?, ?it/s]
# model-00001-of-00003.safetensors:   0%|          | 0.00/4.94G [00:00<?, ?B/s]
# model-00002-of-00003.safetensors:   0%|          | 0.00/5.00G [00:00<?, ?B/s]
# model-00003-of-00003.safetensors:   0%|          | 0.00/4.54G [00:00<?, ?B/s]
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/111 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/1.46k [00:00<?, ?B/s]
# tokenizer.model:   0%|          | 0.00/493k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.80M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/72.0 [00:00<?, ?B/s]

# %%
messages = [ChatMessage.from_user("Who killed Archduke Ferdinand in 1914 and why?")]
llm.run(messages, generation_kwargs={"max_new_tokens": 1350})
# Out:
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Archduke Franz Ferdinand of Austria-Hungary was assassinated on June 28, 1914, in Sarajevo, Bosnia. The assassination was carried out by Gavrilo Princip, a member of a Serbian nationalist group called the Black Hand.
#
# The Black Hand sought to unite all South Slavic peoples under one rule and saw the Austro-Hungarian Archduke, who was also the heir to the Austro-Hungarian throne, as an obstacle to their goals. They believed that the assassination of the Archduke would provoke a war between Austria-Hungary and Serbia, which would ultimately lead to the disintegration of the Austro-Hungarian Empire and the creation of a larger, independent South Slavic state.
#
# The assassination was not an impulsive act. The Black Hand had been planning the assassination for months, and they had several opportunities to carry it out before finally succeeding on June 28. The Archduke and his wife, Sophie, were visiting Sarajevo as part of a tour of the Austro-Hungarian provinces. Their motorcade was attacked as it made its way through the city streets. Princip threw a bomb at the car, which wounded several people but did not kill the Archduke and Sophie. They were taken to the hospital, where Princip shot and killed them both.
#
# The assassination of Archduke Franz Ferdinand is widely regarded as the spark that ignited World War I. Austria-Hungary declared war on Serbia in response, and the conflict quickly escalated as other European powers became involved.</s>
# {'replies': [ChatMessage(content=' Archduke Franz Ferdinand of Austria-Hungary was assassinated on June 28, 1914, in Sarajevo, Bosnia. The assassination was carried out by Gavrilo Princip, a member of a Serbian nationalist group called the Black Hand.\n\nThe Black Hand sought to unite all South Slavic peoples under one rule and saw the Austro-Hungarian Archduke, who was also the heir to the Austro-Hungarian throne, as an obstacle to their goals. They believed that the assassination of the Archduke would provoke a war between Austria-Hungary and Serbia, which would ultimately lead to the disintegration of the Austro-Hungarian Empire and the creation of a larger, independent South Slavic state.\n\nThe assassination was not an impulsive act. The Black Hand had been planning the assassination for months, and they had several opportunities to carry it out before finally succeeding on June 28. The Archduke and his wife, Sophie, were visiting Sarajevo as part of a tour of the Austro-Hungarian provinces. Their motorcade was attacked as it made its way through the city streets. Princip threw a bomb at the car, which wounded several people but did not kill the Archduke and Sophie. They were taken to the hospital, where Princip shot and killed them both.\n\nThe assassination of Archduke Franz Ferdinand is widely regarded as the spark that ignited World War I. Austria-Hungary declared war on Serbia in response, and the conflict quickly escalated as other European powers became involved.', role=<ChatRole.ASSISTANT: 'assistant'>, name=None, meta={})]}
